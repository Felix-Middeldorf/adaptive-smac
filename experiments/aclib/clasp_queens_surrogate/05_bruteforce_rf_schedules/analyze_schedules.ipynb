# %% [markdown]
# # Clasp Queens: brute-force RF schedule analytics
#
# This notebook compares all 50 three-phase RF schedules, the five
# deterministic fixed-depth controls from `03_fixed_deterministic`
# requested for the comparison, and the five matched PCA=4
# fixed-depth controls from `04_fixed_deterministic_pca4`.
#
# Every reported performance is the incumbent configuration's mean
# PAR10 over **all training instances**, evaluated with surrogate
# quantile seed 0. Lower PAR10 is better. Rankings therefore do not
# use SMAC's partial-instance incumbent cost.
#
# The three schedule phases cover trials 0–499, 500–1,999, and
# 2,000–4,999. All schedules use 100 trees, minimum leaf size 1,
# PCA=4, and deterministic target values.

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Markdown, display

HERE = Path.cwd().resolve()
if not (HERE / "schedule_catalog.json").is_file():
    HERE = (
        Path.cwd()
        / "experiments/aclib"
        / "clasp_queens_surrogate"
        / "05_bruteforce_rf_schedules"
    ).resolve()
ACLIB_ROOT = HERE.parents[1]
if str(ACLIB_ROOT) not in sys.path:
    sys.path.insert(0, str(ACLIB_ROOT))

from rf_schedule_notebook_analytics import (
    build_notebook_data,
    findings_markdown,
    plot_checkpoint_trajectories,
    plot_early_vs_final,
    plot_overall_ranking,
    plot_phase_effects,
    plot_rank_stability,
    plot_runtime_performance,
    plot_top_five_by_seed,
    top_five_by_seed,
    top_five_overall,
    top_policy_definitions,
)

BENCHMARK_KEY = "clasp_queens"
DISPLAY_NAME = "Clasp Queens"
plt.rcParams.update({"figure.dpi": 120, "axes.grid": False})
print("Experiment:", HERE)
# Out:
# Experiment: /rwthfs/rz/cluster/home/io632776/experiments/adaptive-smac/experiments/aclib/clasp_queens_surrogate/05_bruteforce_rf_schedules

# %% [markdown]
# ## Data loading and audit
#
# The schedule checkpoint values were already independently
# validated on all training instances. The first execution may
# validate missing fixed-depth incumbents and cache those values in
# the corresponding fixed experiment's `analytics_cache` directory.
#
# The audit table confirms the number of distinct policies and
# seed runs included in each policy class.

# %%
data = build_notebook_data(HERE, BENCHMARK_KEY)
audit = (
    data.policy_rows.groupby("policy_type")
    .agg(
        policies=("policy_id", "nunique"),
        policy_seed_rows=("policy_id", "size"),
        seeds=("smac_seed", "nunique"),
        minimum_final_trials=("par10_5000", "count"),
    )
    .reset_index()
)
display(audit)
assert data.policy_rows["policy_id"].nunique() == 60
assert len(data.policy_rows) == 180
# Out:
#                     policy_type  policies  policy_seed_rows  seeds  \
# 0           fixed depth (PCA=4)         5                15      3
# 1          fixed depth (no PCA)         5                15      3
# 2  three-phase schedule (PCA=4)        50               150      3
#
#    minimum_final_trials
# 0                    15
# 1                    15
# 2                   150

# %% [markdown]
# ## Top five policies for each SMAC seed
#
# Each seed is ranked independently by final full-training PAR10 at
# trial 5,000. This reveals whether one schedule wins consistently
# or whether the preferred schedule depends strongly on SMAC's
# optimization seed. Bars include schedules and both fixed-depth
# control families.

# %%
seed_top5 = top_five_by_seed(data)
display(seed_top5)
plot_top_five_by_seed(data)
plt.show()
# Out:
#     smac_seed  seed_rank     policy_id        policy_label  \
# 0           0          1   schedule_18         Schedule 18
# 1           0          2   schedule_31         Schedule 31
# 2           0          3   schedule_06         Schedule 06
# 3           0          4   schedule_44         Schedule 44
# 4           0          5  fixed_p4_d10   Fixed d10 (PCA=4)
# 5           1          1   schedule_45         Schedule 45
# 6           1          2   schedule_17         Schedule 17
# 7           1          3   schedule_27         Schedule 27
# 8           1          4   schedule_49         Schedule 49
# 9           1          5  fixed_np_d10  Fixed d10 (no PCA)
# 10          2          1   schedule_07         Schedule 07
# 11          2          1   schedule_17         Schedule 17
# 12          2          1   schedule_41         Schedule 41
# 13          2          4   schedule_29         Schedule 29
# 14          2          5  fixed_np_d15  Fixed d15 (no PCA)
#
#                      policy_type  par10_5000  par10_500  improvement_500_5000
# 0   three-phase schedule (PCA=4)   14.362233  69.335164             54.972931
# 1   three-phase schedule (PCA=4)   14.430475  25.692219             11.261744
# 2   three-phase schedule (PCA=4)   15.046725  15.046725              0.000000
# 3   three-phase schedule (PCA=4)   15.361478  20.172738              4.811260
# 4            fixed depth (PCA=4)   16.878342  38.576165             21.697823
# 5   three-phase schedule (PCA=4)   13.610945  29.464404             15.853459
# 6   three-phase schedule (PCA=4)   15.006552  25.375843             10.369290
# 7   three-phase schedule (PCA=4)   16.082638  16.082638              0.000000
# 8   three-phase schedule (PCA=4)   16.372223  67.983583             51.611361
# 9           fixed depth (no PCA)   16.471847  24.826558              8.354711
# 10  three-phase schedule (PCA=4)   12.626724  12.626724              0.000000
# 11  three-phase schedule (PCA=4)   12.626724  12.626724              0.000000
# 12  three-phase schedule (PCA=4)   12.626724  12.626724              0.000000
# 13  three-phase schedule (PCA=4)   13.328393  47.167245             33.838852
# 14          fixed depth (no PCA)   13.683522  44.079400             30.395878

# %% [markdown]
# ## Top five policies across all SMAC seeds
#
# The primary cross-seed ranking uses mean final full-training
# PAR10. Standard deviation, worst-seed performance, mean seed rank,
# and worst seed rank show how much confidence to place in the mean.
# The plot displays the top 15 so near-ties and fixed baselines
# remain visible.

# %%
overall_top5 = top_five_overall(data)
display(overall_top5)
plot_overall_ranking(data, top_n=15)
plt.show()
# Out:
#    overall_rank     policy_id       policy_label  \
# 0             1   schedule_17        Schedule 17
# 1             2  fixed_p4_d10  Fixed d10 (PCA=4)
# 2             3   schedule_40        Schedule 40
# 3             4   schedule_44        Schedule 44
# 4             5  fixed_p4_d20  Fixed d20 (PCA=4)
#
#                     policy_type  final_mean  final_std  final_worst  \
# 0  three-phase schedule (PCA=4)   18.609746   8.386748    28.195962
# 1           fixed depth (PCA=4)   19.324446   4.448196    24.458876
# 2  three-phase schedule (PCA=4)   19.754577   4.320618    24.725444
# 3  three-phase schedule (PCA=4)   20.175721   5.994176    26.889517
# 4           fixed depth (PCA=4)   20.284012   5.099749    25.776676
#
#    mean_seed_rank  worst_seed_rank  improvement_500_5000_mean
# 0       15.333333               43                   5.517791
# 1       14.333333               21                  27.793270
# 2       15.000000               18                  56.170672
# 3       21.333333               39                   7.600823
# 4       18.000000               34                  15.893793

# %% [markdown]
# ## RF definitions of the leading policies
#
# This table expands each leading policy into its depth,
# minimum-split size, and feature ratio in the three phases. Fixed
# controls repeat the same setting in every phase. It makes repeated
# motifs among successful schedules directly visible.

# %%
definitions = top_policy_definitions(data, top_n=12)
display(definitions)
# Out:
#     overall_rank     policy_id  final_mean  final_std  \
# 0              1   schedule_17   18.609746   8.386748
# 1              2  fixed_p4_d10   19.324446   4.448196
# 2              3   schedule_40   19.754577   4.320618
# 3              4   schedule_44   20.175721   5.994176
# 4              5  fixed_p4_d20   20.284012   5.099749
# 5              6   schedule_07   20.890520   7.165379
# 6              7   schedule_18   20.986213   5.862617
# 7              8  fixed_np_d10   21.300613   5.222881
# 8              9   schedule_26   21.423471   5.853581
# 9             10  fixed_np_d30   21.563722   6.857978
# 10            11   schedule_23   21.595990   5.404732
# 11            12   schedule_29   21.775258   7.935323
#
#                      policy_type  phase_0_depth  phase_0_min_samples_split  \
# 0   three-phase schedule (PCA=4)             30                          4
# 1            fixed depth (PCA=4)             10                          1
# 2   three-phase schedule (PCA=4)              5                          4
# 3   three-phase schedule (PCA=4)             15                          8
# 4            fixed depth (PCA=4)             20                          1
# 5   three-phase schedule (PCA=4)             30                          4
# 6   three-phase schedule (PCA=4)             15                          4
# 7           fixed depth (no PCA)             10                          1
# 8   three-phase schedule (PCA=4)             15                          2
# 9           fixed depth (no PCA)             30                          1
# 10  three-phase schedule (PCA=4)             20                          2
# 11  three-phase schedule (PCA=4)             10                          4
#
#     phase_0_feature_ratio  phase_1_depth  phase_1_min_samples_split  \
# 0                0.833333             15                          2
# 1                0.833333             10                          1
# 2                0.500000             10                          2
# 3                0.500000             20                          8
# 4                0.833333             20                          1
# 5                0.833333             15                          4
# 6                1.000000             30                          2
# 7                0.833333             10                          1
# 8                1.000000             30                          4
# 9                0.833333             30                          1
# 10               0.300000             20                          8
# 11               0.833333              5                          2
#
#     phase_1_feature_ratio  phase_2_depth  phase_2_min_samples_split  \
# 0                0.833333              5                          2
# 1                0.833333             10                          1
# 2                1.000000              5                          2
# 3                1.000000              5                          8
# 4                0.833333             20                          1
# 5                0.833333              5                          4
# 6                0.500000             30                          2
# 7                0.833333             10                          1
# 8                0.500000              5                          4
# 9                0.833333             30                          1
# 10               0.300000             20                          8
# 11               0.833333             15                          2
#
#     phase_2_feature_ratio
# 0                0.833333
# 1                0.833333
# 2                1.000000
# 3                1.000000
# 4                0.833333
# 5                0.833333
# 6                0.500000
# 7                0.833333
# 8                0.500000
# 9                0.833333
# 10               0.300000
# 11               0.833333

# %% [markdown]
# ## Comparison with fixed-depth controls
#
# For every schedule and seed, the table compares its final value
# with the best fixed PCA=4 depth for that same seed. Negative deltas
# favor the schedule. Wins count how many of the three seeds the
# schedule beats. The no-PCA controls from `03_fixed_deterministic`
# are also reported, but that delta combines policy and PCA effects.

# %%
fixed_summary = (
    data.aggregate_rankings[
        data.aggregate_rankings["policy_type"].str.startswith("fixed")
    ]
    .sort_values(["policy_type", "final_mean"])
    [
        [
            "policy_label",
            "policy_type",
            "overall_rank",
            "final_mean",
            "final_std",
            "final_worst",
            "mean_seed_rank",
        ]
    ]
)
display(fixed_summary)
display(data.baseline_comparison.head(15))
# Out:
#           policy_label           policy_type  overall_rank  final_mean  \
# 1    Fixed d10 (PCA=4)   fixed depth (PCA=4)             2   19.324446
# 4    Fixed d20 (PCA=4)   fixed depth (PCA=4)             5   20.284012
# 19   Fixed d15 (PCA=4)   fixed depth (PCA=4)            20   23.183269
# 21   Fixed d30 (PCA=4)   fixed depth (PCA=4)            22   23.327693
# 48    Fixed d5 (PCA=4)   fixed depth (PCA=4)            49   30.777613
# 7   Fixed d10 (no PCA)  fixed depth (no PCA)             8   21.300613
# 9   Fixed d30 (no PCA)  fixed depth (no PCA)            10   21.563722
# 14  Fixed d20 (no PCA)  fixed depth (no PCA)            15   22.126026
# 17   Fixed d5 (no PCA)  fixed depth (no PCA)            18   22.547226
# 43  Fixed d15 (no PCA)  fixed depth (no PCA)            44   28.688064
#
#     final_std  final_worst  mean_seed_rank
# 1    4.448196    24.458876       14.333333
# 4    5.099749    25.776676       18.000000
# 19   5.112789    26.758323       27.666667
# 21   7.290868    30.225830       25.666667
# 48   8.315498    40.379359       39.000000
# 7    5.222881    26.844013       16.666667
# 9    6.857978    26.181087       18.666667
# 14   7.467898    27.867997       22.666667
# 17   4.970746    26.263510       22.666667
# 43  22.779846    54.900470       23.666667
#       policy_id policy_label  mean_delta_to_best_fixed_pca4  \
# 0   schedule_17  Schedule 17                      -0.268784
# 1   schedule_18  Schedule 18                       2.107682
# 2   schedule_26  Schedule 26                       2.544940
# 3   schedule_29  Schedule 29                       2.896728
# 4   schedule_40  Schedule 40                       0.876046
# 5   schedule_44  Schedule 44                       1.297190
# 6   schedule_07  Schedule 07                       2.011990
# 7   schedule_23  Schedule 23                       2.717460
# 8   schedule_41  Schedule 41                       3.155631
# 9   schedule_49  Schedule 49                       3.159737
# 10  schedule_31  Schedule 31                       3.358068
# 11  schedule_06  Schedule 06                       3.562625
# 12  schedule_27  Schedule 27                       4.320695
# 13  schedule_14  Schedule 14                       4.708175
# 14  schedule_12  Schedule 12                       4.947586
#
#     wins_vs_best_fixed_pca4  mean_delta_to_best_fixed_no_pca  \
# 0                         2                         1.695963
# 1                         2                         4.072430
# 2                         2                         4.509688
# 3                         2                         4.861476
# 4                         1                         2.840794
# 5                         1                         3.261938
# 6                         1                         3.976737
# 7                         1                         4.682208
# 8                         1                         5.120379
# 9                         1                         5.124485
# 10                        1                         5.322816
# 11                        1                         5.527373
# 12                        1                         6.285443
# 13                        1                         6.672923
# 14                        1                         6.912334
#
#     wins_vs_best_fixed_no_pca
# 0                           2
# 1                           1
# 2                           0
# 3                           1
# 4                           0
# 5                           1
# 6                           1
# 7                           0
# 8                           1
# 9                           1
# 10                          1
# 11                          1
# 12                          1
# 13                          0
# 14                          0

# %% [markdown]
# ## How the leading policies improve over time
#
# Lines show mean incumbent PAR10 at trials 500, 2,000, and 5,000;
# shaded regions span the minimum to maximum across the three SMAC
# seeds. A curve that improves mainly after a switch indicates that
# later-phase settings may be useful, while a flat curve suggests
# most useful progress happened early.

# %%
plot_checkpoint_trajectories(data, top_n=10)
plt.show()

# %% [markdown]
# ## Cross-seed rank stability
#
# The heatmap gives the rank of each overall leading policy within
# every seed. Uniformly low ranks indicate a robust policy; a mix of
# excellent and poor ranks warns that a good mean is driven by one
# favorable seed.

# %%
plot_rank_stability(data, top_n=20)
plt.show()

# %% [markdown]
# ## Early performance versus final performance
#
# This scatter plot tests whether success by trial 500 predicts the
# final result. Points below the general trend are late improvers;
# points that start well but finish poorly may use unsuitable
# settings after a checkpoint.

# %%
plot_early_vs_final(data)
plt.show()

# %% [markdown]
# ## Marginal effects of phase settings
#
# For phase 0, bars show PAR10 at trial 500 and lower is better. For
# phases 1 and 2, bars show improvement during that phase and higher
# is better. Error bars are standard deviations over all
# schedule-seed runs carrying the setting.
#
# These are descriptive associations, not isolated causal effects:
# the 50 schedules are diverse rather than a complete factorial
# design, so settings can be correlated across phases.

# %%
phase_table = data.phase_effects.sort_values(
    ["phase", "factor", "mean"],
    ascending=[True, True, True],
)
display(phase_table)
plot_phase_effects(data)
plt.show()
# Out:
#     phase             factor      value                 metric  \
# 4       0              depth  30.000000              par10_500
# 0       0              depth   5.000000              par10_500
# 3       0              depth  20.000000              par10_500
# 2       0              depth  15.000000              par10_500
# 1       0              depth  10.000000              par10_500
# 11      0      feature_ratio   1.000000              par10_500
# 10      0      feature_ratio   0.833333              par10_500
# 8       0      feature_ratio   0.300000              par10_500
# 9       0      feature_ratio   0.500000              par10_500
# 7       0  min_samples_split   8.000000              par10_500
# 5       0  min_samples_split   2.000000              par10_500
# 6       0  min_samples_split   4.000000              par10_500
# 14      1              depth  15.000000   improvement_500_2000
# 15      1              depth  20.000000   improvement_500_2000
# 12      1              depth   5.000000   improvement_500_2000
# 16      1              depth  30.000000   improvement_500_2000
# 13      1              depth  10.000000   improvement_500_2000
# 22      1      feature_ratio   0.833333   improvement_500_2000
# 21      1      feature_ratio   0.500000   improvement_500_2000
# 23      1      feature_ratio   1.000000   improvement_500_2000
# 20      1      feature_ratio   0.300000   improvement_500_2000
# 18      1  min_samples_split   4.000000   improvement_500_2000
# 19      1  min_samples_split   8.000000   improvement_500_2000
# 17      1  min_samples_split   2.000000   improvement_500_2000
# 24      2              depth   5.000000  improvement_2000_5000
# 28      2              depth  30.000000  improvement_2000_5000
# 25      2              depth  10.000000  improvement_2000_5000
# 27      2              depth  20.000000  improvement_2000_5000
# 26      2              depth  15.000000  improvement_2000_5000
# 32      2      feature_ratio   0.300000  improvement_2000_5000
# 33      2      feature_ratio   0.500000  improvement_2000_5000
# 35      2      feature_ratio   1.000000  improvement_2000_5000
# 34      2      feature_ratio   0.833333  improvement_2000_5000
# 31      2  min_samples_split   8.000000  improvement_2000_5000
# 29      2  min_samples_split   2.000000  improvement_2000_5000
# 30      2  min_samples_split   4.000000  improvement_2000_5000
#
#            direction  runs  schedules       mean     median        std  \
# 4    lower is better    30         10  40.664092  38.576165  17.129441
# 0    lower is better    36         12  44.835282  40.018238  20.671476
# 3    lower is better    27          9  50.129583  54.029836  21.505428
# 2    lower is better    33         11  53.053533  48.171205  21.088972
# 1    lower is better    24          8  59.195673  61.525821  15.449294
# 11   lower is better    39         13  45.895597  40.379359  15.764391
# 10   lower is better    42         14  48.215625  47.597726  19.956341
# 8    lower is better    39         13  48.441753  40.018238  23.780034
# 9    lower is better    30         10  55.158049  62.017571  20.493374
# 7    lower is better    48         16  43.598192  40.018238  18.401267
# 5    lower is better    48         16  47.372853  40.379359  16.080690
# 6    lower is better    54         18  55.413782  58.657831  23.461861
# 14  higher is better    51         17   8.236210   0.000000  14.323158
# 15  higher is better    21          7   8.901632   0.000000  18.042746
# 12  higher is better    27          9  11.137758   3.364003  14.861510
# 16  higher is better    27          9  11.778854   3.894310  17.562106
# 13  higher is better    24          8  19.355946  11.839301  21.325560
# 22  higher is better    42         14   6.803825   0.000000  13.383248
# 21  higher is better    42         14  11.414477   5.242385  14.961856
# 23  higher is better    33         11  13.771816   3.801214  18.396940
# 20  higher is better    33         11  14.261625   0.000000  21.258276
# 18  higher is better    66         22  10.358560   0.490453  17.349291
# 19  higher is better    42         14  10.578141   4.691948  13.952212
# 17  higher is better    42         14  13.388699   2.181682  19.345544
# 24  higher is better    33         11   7.914766   1.676512  12.760030
# 28  higher is better    27          9   8.214377   0.000000  14.895156
# 25  higher is better    27          9   8.575852   2.389700  13.257270
# 27  higher is better    27          9   9.061812   1.616457  12.658782
# 26  higher is better    36         12  16.917701   9.717419  17.827013
# 32  higher is better    36         12   8.355162   1.660754  15.762202
# 33  higher is better    33         11   9.101473   1.521188  12.180382
# 35  higher is better    36         12   9.904226   1.973204  13.917392
# 34  higher is better    45         15  13.567624   3.851544  16.479338
# 31  higher is better    45         15   6.831591   0.140953  11.987145
# 29  higher is better    45         15   9.222820   1.820771  12.386704
# 30  higher is better    60         20  14.096352   6.751709  17.616221
#
#     final_mean
# 4    26.682231
# 0    26.017447
# 3    27.796380
# 2    27.016011
# 1    30.055287
# 11   26.561883
# 10   26.913547
# 8    27.059933
# 9    29.294424
# 7    27.823782
# 5    27.400041
# 6    26.846463
# 14   27.707645
# 15   26.105657
# 12   28.358189
# 16   26.649175
# 13   27.247709
# 22   26.913547
# 21   27.194151
# 23   28.493067
# 20   26.898727
# 18   27.883819
# 19   27.891998
# 17   25.920393
# 24   23.292004
# 28   25.676986
# 25   32.574280
# 27   28.443696
# 26   27.529233
# 32   26.562789
# 33   26.448755
# 35   29.250113
# 34   27.075091
# 31   28.416382
# 29   26.615458
# 30   27.066995

# %% [markdown]
# ## Runtime–performance trade-off
#
# The plot shows whether better policies systematically require more
# wall time. Runtime is averaged across seeds. Cluster placement
# also affects wall time, so this is useful for screening expensive
# settings but should not be interpreted as a pure RF-cost
# measurement.

# %%
plot_runtime_performance(data)
plt.show()

# %% [markdown]
# ## Automatically calculated findings
#
# These statements summarize the current cached results and update
# automatically if the experiment data are replaced.

# %%
display(Markdown(findings_markdown(data)))
# Out:
# - **Best mean final policy:** Schedule 17 with PAR10 18.61 ± 8.387.
# - **Best worst-seed robustness:** Schedule 40; its worst seed rank is 18.
# - **Schedules versus the best fixed PCA=4 depth:** 0 schedules win on all three seeds and 4 win on at least two seeds.
# - **Early/final Spearman correlation among schedules:** 0.405. Values near one mean early ranking is strongly predictive; values near zero favor adaptive decisions.
# - **Runtime/final Spearman correlation among schedules:** 0.040. A negative value means slower schedules tended to finish better.
# - The no-PCA fixed controls from `03_fixed_deterministic` are included as requested, but schedule-versus-fixed conclusions should primarily use the PCA=4 fixed controls because all three-phase schedules use PCA=4.
